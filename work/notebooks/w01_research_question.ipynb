# %% [markdown]
# <a href="https://colab.research.google.com/github/anason-arch/flyrank-ml/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/anason-arch/flyrank-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# I chose the **Ranking Signal Analysis** lane because I want to understand which search ranking signals are associated with better performing pages. This lane will help me analyze the available data, identify useful patterns, and make evidence based recommendations instead of relying on guesses. It also provides a strong foundation for the remaining weeks of the internship.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# **Decision:** Which pages should be prioritized for improvement based on their ranking signals?
#
# **Action:** An SEO or content team can focus on improving the pages that show weak ranking signals.
#
# **Cost of a wrong recommendation:** If the wrong pages are prioritized, time and resources may be wasted, and important pages that could improve search performance might be ignored.
#
# **Why ML/Data helps:** Data allows us to measure patterns across many pages, while machine learning can identify useful relationships that are difficult to find manually.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# The starter dataset contains 30,000 rows and 44 columns. It includes important ranking signals such as CTR, average position, engagement rate, search volume, and competition. These metrics provide enough real data to investigate which factors are associated with better search performance over the next seven weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
# !git clone https://github.com/anason-arch/flyrank-ml.git
# Out:
# Cloning into 'flyrank-ml'...
# remote: Enumerating objects: 119, done.
# remote: Counting objects: 100% (119/119), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 119 (delta 36), reused 95 (delta 29), pack-reused 0 (from 0)
# Receiving objects: 100% (119/119), 1.84 MiB | 12.58 MiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %%
import pandas as pd

df = pd.read_csv("flyrank-ml/data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
print(df.head())
# Out:
# Rows: 30000
# Columns: 44
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This work is intended to provide decision support based on observed patterns in the data. It does not prove causation or predict how search engines work internally. Any recommendations should be treated as evidence-based guidance rather than guaranteed outcomes.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
